# %% [markdown]
# <a href="https://colab.research.google.com/github/Marvinyesid01/ACA-1-OK/blob/main/ACA_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
septiembre2023=pd.read_csv("https://raw.githubusercontent.com/Marvinyesid01/ACA-3/main/Septiembre%202023%20exportaciones%20Colom.csv")
octubre2023=pd.read_csv("https://raw.githubusercontent.com/Marvinyesid01/ACA-3/main/Octubre%202023%20exportaciones%20Colom.csv")
noviembre2023=pd.read_csv("https://raw.githubusercontent.com/Marvinyesid01/ACA-3/main/Noviembre%202023%20exportaciones%20Colom.csv")

# %%
septiembre2023.head()
# Out:
#    FECH  ADUA  PAIS COD_PAI4  COD_SAL1 COD_SAL  DPTO2  VIA  BANDERA  REGIM  \
# 0  2309     1   249      USA         0     AXM     68    9      249      1
# 1  2309     1   580      PAN         0     AXM     68    0      580      1
# 2  2309     3    17      ALB         3     BOG     11    3       23      1
# 3  2309     3    23      DEU         3     BOG      5    3       23      1
# 4  2309     3    23      DEU         3     BOG      5    3       23      1
#
#    ...  CER_ORI1  SISESP  DPTO1  UNID  CODUNI2  CANTI      PBK      PNK  \
# 0  ...         8       2     68    67       M3    102  90943.0  82676.0
# 1  ...         8       2     68    67       M3     11  11047.0   9206.0
# 2  ...         8       2     11    11        U      3    622.0    555.0
# 3  ...         8       2      5    33       KG     10     10.0     10.0
# 4  ...         8       2      5    33       KG      3      3.0      3.0
#
#    FOBDOL     FOBPES
# 0   99637  393657500
# 1    9517   37601143
# ...

# %%
octubre2023.head()
# Out:
#    FECH  ADUA  PAIS COD_PAI4  COD_SAL1 COD_SAL  DPTO2  VIA  BANDERA  REGIM  \
# 0  2310     1   249      USA         0     AXM     68    9      249      1
# 1  2310     1   580      PAN         0     AXM     68    0      580      1
# 2  2310     3    23      DEU         3     BOG      5    3       23      1
# 3  2310     3    23      DEU         3     BOG      5    3       23      1
# 4  2310     3    23      DEU         3     BOG      5    3       23      1
#
#    ...  CER_ORI1  SISESP  DPTO1  UNID  CODUNI2  CANTI       PBK      PNK  \
# 0  ...         8       2     68    67       M3    110  115667.0  88975.0
# 1  ...         8       2     68    67       M3     22   22674.0  17442.0
# 2  ...         6       2      5    33       KG    576     654.0    576.0
# 3  ...         8       2      5    33       KG     84     101.0     84.0
# 4  ...         8       2      5    33       KG     30      36.0     30.0
#
#    FOBDOL     FOBPES
# 0  108083  457256555
# 1   18547   78465124
# ...

# %%
noviembre2023.head()
# Out:
#    FECH  ADUA  PAIS COD_PAI4  COD_SAL1 COD_SAL  DPTO2  VIA  BANDERA  REGIM  \
# 0  2311     1   249      USA         0     AXM     68    9      249      1
# 1  2311     1   580      PAN         0     AXM     68    0      580      1
# 2  2311     3    23      DEU         3     BOG      5    3       23      1
# 3  2311     3    23      DEU         3     BOG      5    3       23      1
# 4  2311     3    23      DEU         3     BOG      5    3       23      1
#
#    ...  CER_ORI1  SISESP  DPTO1  UNID  CODUNI2  CANTI    PBK    PNK  FOBDOL  \
# 0  ...         8       2     68    67       M3     95  84377  76706  104645
# 1  ...         8       2     68    67       M3     12  10845   9859   12125
# 2  ...         8       2      5    33       KG    480    584    480    3000
# 3  ...         8       2      5    33       KG     90    109     90     635
# 4  ...         8       2      5    33       KG     60     73     60     228
#
#       FOBPES
# 0  422470536
# 1   48952665
# 2   12111570
# ...

# %%
septiembre2023.describe()
# Out:
#           FECH          ADUA          PAIS      COD_SAL1         DPTO2  \
# count  38919.0  38919.000000  38919.000000  38919.000000  38919.000000
# mean    2309.0     37.289088    368.246718     13.845577     22.365657
# std        0.0     27.892353    211.722773     14.129948     23.270321
# min     2309.0      1.000000     17.000000      0.000000      0.000000
# 25%     2309.0      3.000000    239.000000      3.000000      5.000000
# 50%     2309.0     37.000000    249.000000      6.000000     11.000000
# 75%     2309.0     48.000000    580.000000     35.000000     25.000000
# max     2309.0     90.000000    954.000000     46.000000     86.000000
#
#                 VIA       BANDERA         REGIM         MODAD       FINALID  \
# count  38919.000000  38919.000000  38919.000000  38919.000000  38919.000000
# mean       4.903286    397.955523      1.015674    189.346386      1.086590
# std        3.629566    218.467860      0.240255     39.202122      0.281237
# ...

# %%
septiembre2023.describe().T
# Out:
#             count          mean           std     min        25%         50%  \
# FECH      38919.0  2.309000e+03  0.000000e+00  2309.0     2309.0      2309.0
# ADUA      38919.0  3.728909e+01  2.789235e+01     1.0        3.0        37.0
# PAIS      38919.0  3.682467e+02  2.117228e+02    17.0      239.0       249.0
# COD_SAL1  38919.0  1.384558e+01  1.412995e+01     0.0        3.0         6.0
# DPTO2     38919.0  2.236566e+01  2.327032e+01     0.0        5.0        11.0
# VIA       38919.0  4.903286e+00  3.629566e+00     0.0        1.0         4.0
# BANDERA   38919.0  3.979555e+02  2.184679e+02    23.0      211.0       351.0
# REGIM     38919.0  1.015674e+00  2.402548e-01     1.0        1.0         1.0
# MODAD     38919.0  1.893464e+02  3.920212e+01     2.0      198.0       198.0
# FINALID   38919.0  1.086590e+00  2.812371e-01     1.0        1.0         1.0
# CER_ORI1  38919.0  7.268738e+00  1.978924e+00     1.0        8.0         8.0
# ...

# %%
octubre2023.describe().T
# Out:
#             count          mean           std     min        25%         50%  \
# FECH      41159.0  2.310000e+03  0.000000e+00  2310.0     2310.0      2310.0
# ADUA      41159.0  3.779062e+01  2.796231e+01     1.0        3.0        37.0
# PAIS      41159.0  3.697385e+02  2.133040e+02    23.0      239.0       249.0
# COD_SAL1  41159.0  1.370388e+01  1.400724e+01     0.0        3.0         6.0
# DPTO2     41159.0  2.290617e+01  2.379217e+01     0.0        8.0        11.0
# VIA       41159.0  4.977502e+00  3.623214e+00     0.0        1.0         7.0
# BANDERA   41159.0  3.983763e+02  2.229030e+02    23.0      211.0       431.0
# REGIM     41159.0  1.014869e+00  2.361320e-01     1.0        1.0         1.0
# MODAD     41159.0  1.900915e+02  3.799729e+01     2.0      198.0       198.0
# FINALID   41159.0  1.086178e+00  2.806301e-01     1.0        1.0         1.0
# CER_ORI1  41159.0  7.322044e+00  1.909617e+00     1.0        8.0         8.0
# ...

# %%
consolidado=["FOBDOL","FOBPES", "CANTI"]
septiembre2023[consolidado].sum()
# Out:
# FOBDOL        4127367342
# FOBPES    16523865858966
# CANTI         7793778239
# dtype: int64

# %%
consolidado=["FOBDOL","FOBPES", "CANTI"]
octubre2023[consolidado].sum()
# Out:
# FOBDOL        4150828582
# FOBPES    17486861248813
# CANTI         7819885901
# dtype: int64

# %%
consolidado=["FOBDOL","FOBPES", "CANTI"]
noviembre2023[consolidado].sum()
# Out:
# FOBDOL        4194635191
# FOBPES    16912265191714
# CANTI        14587052052
# dtype: int64
